# %%
import pandas as pd

print("Python OK")
# Out:
# Python OK

# %%
import os

os.listdir()
# Out:
# ['.anaconda',
#  '.android',
#  '.codex',
#  '.conda',
#  '.continuum',
#  '.emulator_console_auth_token',
#  '.gradle',
#  '.idlerc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.matplotlib',
#  '.ms-ad',
#  '.virtual_documents',
#  '.vscode',
#  'anaconda3',
#  'anaconda_projects',
#  'ansel',
#  'AppData',
#  'Application Data',
#  'Contacts',
#  'Cookies',
#  'Data',
#  'Desktop',
#  'Doctor Web',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'Links',
#  'Local Settings',
#  'Music',
#  'NetHood',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{2ad838bc-efea-11ee-a54d-000d3a94eaa1}.TM.blf',
#  'NTUSER.DAT{2ad838bc-efea-11ee-a54d-000d3a94eaa1}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{2ad838bc-efea-11ee-a54d-000d3a94eaa1}.TMContainer00000000000000000002.regtrans-ms',
#  'ntuser.ini',
#  'OneDrive',
#  'Pictures',
#  'PrintHood',
#  'Recent',
#  'Saved Games',
#  'Searches',
#  'SendTo',
#  'Untitled.ipynb',
#  'Videos',
#  'главное меню',
#  'Мои документы',
#  'Шаблоны']

# %%
df = pd.read_excel("data/Online Retail.xlsx")
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
df.info()
df.describe()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
df[df["Quantity"] < 0].head()
df[df["UnitPrice"] == 0].head()
# Out:
#      InvoiceNo StockCode Description  Quantity         InvoiceDate  UnitPrice  \
# 622     536414     22139         NaN        56 2010-12-01 11:52:00        0.0
# 1970    536545     21134         NaN         1 2010-12-01 14:32:00        0.0
# 1971    536546     22145         NaN         1 2010-12-01 14:33:00        0.0
# 1972    536547     37509         NaN         1 2010-12-01 14:33:00        0.0
# 1987    536549    85226A         NaN         1 2010-12-01 14:34:00        0.0
#
#       CustomerID         Country
# 622          NaN  United Kingdom
# 1970         NaN  United Kingdom
# 1971         NaN  United Kingdom
# 1972         NaN  United Kingdom
# 1987         NaN  United Kingdom

# %%
df_clean = df[
    (df["Quantity"] > 0) &
    (df["UnitPrice"] > 0) &
    (~df["InvoiceNo"].str.startswith("C"))
]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 4
#       1 df_clean = df[
#       2     (df["Quantity"] > 0) &
#       3     (df["UnitPrice"] > 0) &
# ----> 4     (~df["InvoiceNo"].str.startswith("C"))
#       5 ]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:1574, in NDFrame.__invert__(self)
#    1570 if not self.size:
#    1571     # inv fails with 0 len
#    1572     return self.copy(deep=False)
# -> 1574 new_data = self._mgr.apply(operator.invert)
#    1575 res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    1576 return res.__finalize__(self, method="__invert__")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:361, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     358             kwargs[k] = obj[b.mgr_locs.indexer]
#     360 if callable(f):
# --> 361     applied = b.apply(f, **kwargs)
#     362 else:
#     363     applied = getattr(b, f)(**kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:395, in Block.apply(self, func, **kwargs)
#     389 @final
#     390 def apply(self, func, **kwargs) -> list[Block]:
#     391     """
#     392     apply the function to my values; return a block if we are not
#     393     one
#     394     """
# --> 395     result = func(self.values, **kwargs)
#     397     result = maybe_coerce_values(result)
#     398     return self._split_op_result(result)
#
# TypeError: bad operand type for unary ~: 'float'

# %%
df_clean = df[
    (df["Quantity"] > 0) &
    (df["UnitPrice"] > 0) &
    (~df["InvoiceNo"].str.startswith("C"))
]
df_clean["Revenue"] = df_clean["Quantity"] * df_clean["UnitPrice"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 4
#       1 df_clean = df[
#       2     (df["Quantity"] > 0) &
#       3     (df["UnitPrice"] > 0) &
# ----> 4     (~df["InvoiceNo"].str.startswith("C"))
#       5 ]
#       6 df_clean["Revenue"] = df_clean["Quantity"] * df_clean["UnitPrice"]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:1574, in NDFrame.__invert__(self)
#    1570 if not self.size:
#    1571     # inv fails with 0 len
#    1572     return self.copy(deep=False)
# -> 1574 new_data = self._mgr.apply(operator.invert)
#    1575 res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    1576 return res.__finalize__(self, method="__invert__")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:361, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     358             kwargs[k] = obj[b.mgr_locs.indexer]
#     360 if callable(f):
# --> 361     applied = b.apply(f, **kwargs)
#     362 else:
#     363     applied = getattr(b, f)(**kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:395, in Block.apply(self, func, **kwargs)
#     389 @final
#     390 def apply(self, func, **kwargs) -> list[Block]:
#     391     """
#     392     apply the function to my values; return a block if we are not
#     393     one
#     394     """
# --> 395     result = func(self.values, **kwargs)
#     397     result = maybe_coerce_values(result)
#     398     return self._split_op_result(result)
#
# TypeError: bad operand type for unary ~: 'float'

# %%
df_clean = df[
    (df["Quantity"] > 0) &
    (df["UnitPrice"] > 0) &
    (~df["InvoiceNo"].str.startswith("C"))
]
df_clean["Revenue"] = df_clean["Quantity"] * df_clean["UnitPrice"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 4
#       1 df_clean = df[
#       2     (df["Quantity"] > 0) &
#       3     (df["UnitPrice"] > 0) &
# ----> 4     (~df["InvoiceNo"].str.startswith("C"))
#       5 ]
#       6 df_clean["Revenue"] = df_clean["Quantity"] * df_clean["UnitPrice"]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:1574, in NDFrame.__invert__(self)
#    1570 if not self.size:
#    1571     # inv fails with 0 len
#    1572     return self.copy(deep=False)
# -> 1574 new_data = self._mgr.apply(operator.invert)
#    1575 res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    1576 return res.__finalize__(self, method="__invert__")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:361, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     358             kwargs[k] = obj[b.mgr_locs.indexer]
#     360 if callable(f):
# --> 361     applied = b.apply(f, **kwargs)
#     362 else:
#     363     applied = getattr(b, f)(**kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:395, in Block.apply(self, func, **kwargs)
#     389 @final
#     390 def apply(self, func, **kwargs) -> list[Block]:
#     391     """
#     392     apply the function to my values; return a block if we are not
#     393     one
#     394     """
# --> 395     result = func(self.values, **kwargs)
#     397     result = maybe_coerce_values(result)
#     398     return self._split_op_result(result)
#
# TypeError: bad operand type for unary ~: 'float'

# %%
df_clean = df[
    (df["Quantity"] > 0) &
    (df["UnitPrice"] > 0) &
    (~df["InvoiceNo"].str.startswith("C"))
]
df_clean["Revenue"] = df_clean["Quantity"] * df_clean["UnitPrice"]
df_clean.head()
df_clean.describe()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 4
#       1 df_clean = df[
#       2     (df["Quantity"] > 0) &
#       3     (df["UnitPrice"] > 0) &
# ----> 4     (~df["InvoiceNo"].str.startswith("C"))
#       5 ]
#       6 df_clean["Revenue"] = df_clean["Quantity"] * df_clean["UnitPrice"]
#       7 df_clean.head()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:1574, in NDFrame.__invert__(self)
#    1570 if not self.size:
#    1571     # inv fails with 0 len
#    1572     return self.copy(deep=False)
# -> 1574 new_data = self._mgr.apply(operator.invert)
#    1575 res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    1576 return res.__finalize__(self, method="__invert__")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:361, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     358             kwargs[k] = obj[b.mgr_locs.indexer]
#     360 if callable(f):
# --> 361     applied = b.apply(f, **kwargs)
#     362 else:
#     363     applied = getattr(b, f)(**kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:395, in Block.apply(self, func, **kwargs)
#     389 @final
#     390 def apply(self, func, **kwargs) -> list[Block]:
#     391     """
#     392     apply the function to my values; return a block if we are not
#     393     one
#     394     """
# --> 395     result = func(self.values, **kwargs)
#     397     result = maybe_coerce_values(result)
#     398     return self._split_op_result(result)
#
# TypeError: bad operand type for unary ~: 'float'

# %%
df_clean = df[
    (df["Quantity"] > 0) &
    (df["UnitPrice"] > 0) &
    (~df["InvoiceNo"].astype(str).str.startswith("C"))
]

# %%
df_clean["Revenue"] = df_clean["Quantity"] * df_clean["UnitPrice"]
df_clean.head()
df_clean.describe()
# Out:
# C:\Users\Admim_Sasha\AppData\Local\Temp\ipykernel_14672\3342304837.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean["Revenue"] = df_clean["Quantity"] * df_clean["UnitPrice"]
#             Quantity                    InvoiceDate      UnitPrice  \
# count  530104.000000                         530104  530104.000000
# mean       10.542037  2011-07-04 20:16:05.225087744       3.907625
# min         1.000000            2010-12-01 08:26:00       0.001000
# 25%         1.000000            2011-03-28 12:22:00       1.250000
# 50%         3.000000            2011-07-20 12:58:00       2.080000
# 75%        10.000000            2011-10-19 12:39:00       4.130000
# max     80995.000000            2011-12-09 12:50:00   13541.330000
# std       155.524124                            NaN      35.915681
#
#           CustomerID        Revenue
# count  397884.000000  530104.000000
# mean    15294.423453      20.121871
# min     12346.000000       0.001000
# 25%     13969.000000       3.750000
# 50%     15159.000000       9.900000
# 75%     16795.000000      17.700000
# max     18287.000000  168469.600000
# std      1713.141560     270.356743

# %%
df_clean = df[
    (df["Quantity"] > 0) &
    (df["UnitPrice"] > 0) &
    (~df["InvoiceNo"].astype(str).str.startswith("C"))
].copy()

# %%
df_clean["Revenue"] = df_clean["Quantity"] * df_clean["UnitPrice"]

# %%
df_clean.shape
# Out:
# (530104, 9)

# %%
df_clean["Revenue"].sum()
# Out:
# np.float64(10666684.544)

# %%
round(df_clean["Revenue"].sum(), 2)
# Out:
# np.float64(10666684.54)

# %%
df_clean["YearMonth"] = df_clean["InvoiceDate"].dt.to_period("M")

# %%
monthly_revenue = df_clean.groupby("YearMonth")["Revenue"].sum()
monthly_revenue
# Out:
# YearMonth
# 2010-12     823746.140
# 2011-01     691364.560
# 2011-02     523631.890
# 2011-03     717639.360
# 2011-04     537808.621
# 2011-05     770536.020
# 2011-06     761739.900
# 2011-07     719221.191
# 2011-08     759138.380
# 2011-09    1058590.172
# 2011-10    1154979.300
# 2011-11    1509496.330
# 2011-12     638792.680
# Freq: M, Name: Revenue, dtype: float64

# %%
monthly_revenue.plot()
# Out:
# <Axes: xlabel='YearMonth'>

# %%
df_clean.groupby("Country")["Revenue"].sum().sort_values(ascending=False).head(10)
# Out:
# Country
# United Kingdom    9025222.084
# Netherlands        285446.340
# EIRE               283453.960
# Germany            228867.140
# France             209715.110
# Australia          138521.310
# Spain               61577.110
# Switzerland         57089.900
# Belgium             41196.340
# Sweden              38378.330
# Name: Revenue, dtype: float64

# %%
total = df_clean["Revenue"].sum()

country_share = df_clean.groupby("Country")["Revenue"].sum() / total * 100
country_share.sort_values(ascending=False).head(5)
# Out:
# Country
# United Kingdom    84.611315
# Netherlands        2.676055
# EIRE               2.657376
# Germany            2.145626
# France             1.966076
# Name: Revenue, dtype: float64

# %%
import sqlite3

conn = sqlite3.connect("ecommerce.db")
df_clean.to_sql("sales", conn, if_exists="replace", index=False)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[22], line 4
#       1 import sqlite3
#       3 conn = sqlite3.connect("ecommerce.db")
# ----> 4 df_clean.to_sql("sales", conn, if_exists="replace", index=False)
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:3109, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2911 """
#    2912 Write records stored in a DataFrame to a SQL database.
#    2913
#    (...)   3105 [(1,), (None,), (2,)]
#    3106 """  # noqa: E501
#    3107 from pandas.io import sql
# -> 3109 return sql.to_sql(
#    3110     self,
#    3111     name,
#    3112     con,
#    3113     schema=schema,
#    3114     if_exists=if_exists,
#    3115     index=index,
#    3116     index_label=index_label,
#    3117     chunksize=chunksize,
#    3118     dtype=dtype,
#    3119     method=method,
#    3120 )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\sql.py:844, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     839     raise NotImplementedError(
#     840         "'frame' argument should be either a Series or a DataFrame"
#     841     )
#     843 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 844     return pandas_sql.to_sql(
#     845         frame,
#     846         name,
#     847         if_exists=if_exists,
#     848         index=index,
#     849         index_label=index_label,
#     850         schema=schema,
#     851         chunksize=chunksize,
#     852         dtype=dtype,
#     853         method=method,
#     854         engine=engine,
#     855         **engine_kwargs,
#     856     )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\sql.py:2841, in SQLiteDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    2831 table = SQLiteTable(
#    2832     name,
#    2833     self,
#    (...)   2838     dtype=dtype,
#    2839 )
#    2840 table.create()
# -> 2841 return table.insert(chunksize, method)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\sql.py:1121, in SQLTable.insert(self, chunksize, method)
#    1118     break
#    1120 chunk_iter = zip(*(arr[start_i:end_i] for arr in data_list))
# -> 1121 num_inserted = exec_insert(conn, keys, chunk_iter)
#    1122 # GH 46891
#    1123 if num_inserted is not None:
#
# File ~\anaconda3\Lib\site-packages\pandas\io\sql.py:2537, in SQLiteTable._execute_insert(self, conn, keys, data_iter)
#    2535 def _execute_insert(self, conn, keys, data_iter) -> int:
#    2536     data_list = list(data_iter)
# -> 2537     conn.executemany(self.insert_statement(num_rows=1), data_list)
#    2538     return conn.rowcount
#
# ProgrammingError: Error binding parameter 10: type 'Period' is not supported

# %%
df_clean["YearMonth"] = df_clean["InvoiceDate"].dt.to_period("M").astype(str)

# %%
import sqlite3

conn = sqlite3.connect("ecommerce.db")
df_clean.to_sql("sales", conn, if_exists="replace", index=False)
# Out:
# 530104

# %%
pd.read_sql("SELECT * FROM sales LIMIT 5;", conn)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#            InvoiceDate  UnitPrice  CustomerID         Country  Revenue  \
# 0  2010-12-01 08:26:00       2.55     17850.0  United Kingdom    15.30
# 1  2010-12-01 08:26:00       3.39     17850.0  United Kingdom    20.34
# 2  2010-12-01 08:26:00       2.75     17850.0  United Kingdom    22.00
# 3  2010-12-01 08:26:00       3.39     17850.0  United Kingdom    20.34
# 4  2010-12-01 08:26:00       3.39     17850.0  United Kingdom    20.34
#
#   YearMonth
# 0   2010-12
# 1   2010-12
# 2   2010-12
# 3   2010-12
# 4   2010-12

# %%
pd.read_sql("""
SELECT SUM(Quantity * UnitPrice) AS total_revenue
FROM sales;
""", conn)
# Out:
#    total_revenue
# 0   1.066668e+07

# %%
pd.read_sql("""
SELECT ROUND(SUM(Quantity * UnitPrice), 2) AS total_revenue
FROM sales;
""", conn)
# Out:
#    total_revenue
# 0    10666684.54

# %%
SELECT 
    Country,
    ROUND(SUM(Quantity * UnitPrice), 2) AS revenue
FROM sales
GROUP BY Country
ORDER BY revenue DESC
LIMIT 5;
# Out:
#   Cell In[28], line 2
#     Country,
#     ^
# IndentationError: unexpected indent
